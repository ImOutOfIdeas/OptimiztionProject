# %%
import cvxpy as cp
# Out:
# (CVXPY) Nov 29 02:25:20 PM: Encountered unexpected exception importing solver OSQP:
# ImportError('DLL load failed while importing qdldl: The specified module could not be found.')

# %%
p = cp.Variable(6, integer = True)
i = cp.Variable(15, integer = True)

obj_func = 250*p[0] + 180*p[1] + 150*p[2] + 170*p[3] + 210*p[4] + 150*p[5] + 210*i[0] + 210*i[1] + 130*i[2] + 130*i[3] + 230*i[4] + 25*i[5] + 80*i[6] + 15*i[7] + 30*i[8] + 110*i[9] + 20*i[10] + 110*i[11] + 5*i[12] + 120*i[13] + 320*i[14]

constraints = []

constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] >= 17)
constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] <= 59)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] >= 75)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] <= 100)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] >= 15)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] <= 30)
constraints.append(11.75*p[0] + 8.75*p[1] + 10.5*p[2] + 10.5*p[3] + 9.4*p[4] + 8.75*p[5] + 2.65*i[4] + 1.55*i[13] + .5*i[14] <= 12.00)
constraints.append(p[0] >= 0)
constraints.append(p[1] >= 0)
constraints.append(p[2] >= 0)
constraints.append(p[3] >= 0)
constraints.append(p[4] >= 0)
constraints.append(p[5] >= 0)
constraints.append(i[0] >= 0)
constraints.append(i[1] >= 0)
constraints.append(i[2] >= 0)
constraints.append(i[3] >= 0)
constraints.append(i[4] >= 0)
constraints.append(i[5] >= 0)
constraints.append(i[6] >= 0)
constraints.append(i[7] >= 0)
constraints.append(i[8] >= 0)
constraints.append(i[9] >= 0)
constraints.append(i[10] >= 0)
constraints.append(i[11] >= 0)
constraints.append(i[12] >= 0)
constraints.append(i[13] >= 0)
constraints.append(i[14] >= 0)
constraints.append(p[0] <= 1)
constraints.append(p[1] <= 1)
constraints.append(p[2] <= 1)
constraints.append(p[3] <= 1)
constraints.append(p[4] <= 1)
constraints.append(p[5] <= 1)
constraints.append(i[0] <= 1)
constraints.append(i[1] <= 1)
constraints.append(i[2] <= 1)
constraints.append(i[3] <= 1)
constraints.append(i[4] <= 1)
constraints.append(i[5] <= 1)
constraints.append(i[6] <= 1)
constraints.append(i[7] <= 1)
constraints.append(i[8] <= 1)
constraints.append(i[9] <= 1)
constraints.append(i[10] <= 1)
constraints.append(i[11] <= 1)
constraints.append(i[12] <= 1)
constraints.append(i[13] <= 1)
constraints.append(i[14] <= 1)


problem = cp.Problem(cp.Maximize(obj_func), constraints)


problem.solve(solver=cp.GUROBI, verbose = True)

print("obj_func =")
print(obj_func.value)
print("p =")
print(p.value)
print("i = ")
print(i.value)
# Out:
# ...
#                                      CVXPY
#                                      v1.3.2
# ...
# (CVXPY) Nov 29 02:25:38 PM: Your problem has 21 variables, 49 constraints, and 0 parameters.
# (CVXPY) Nov 29 02:25:38 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 29 02:25:38 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 29 02:25:38 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 29 02:25:38 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Nov 29 02:25:38 PM: Reduction chain: FlipObjective -> CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# ...

# %%
p = cp.Variable(6, integer = True)
i = cp.Variable(15, integer = True)

obj_func = 250*p[0] + 180*p[1] + 150*p[2] + 170*p[3] + 210*p[4] + 150*p[5] + 210*i[0] + 210*i[1] + 130*i[2] + 130*i[3] + 230*i[4] + 25*i[5] + 80*i[6] + 15*i[7] + 30*i[8] + 110*i[9] + 20*i[10] + 110*i[11] + 5*i[12] + 120*i[13] + 320*i[14]

constraints = []

constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] >= 17)
constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] <= 59)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] >= 75)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] <= 100)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] >= 15)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] <= 30)
constraints.append(11.75*p[0] + 8.75*p[1] + 10.5*p[2] + 10.5*p[3] + 9.4*p[4] + 8.75*p[5] + 2.65*i[4] + 1.55*i[13] + .5*i[14] <= 11.00)
constraints.append(p[0] >= 0)
constraints.append(p[1] >= 0)
constraints.append(p[2] >= 0)
constraints.append(p[3] >= 0)
constraints.append(p[4] >= 0)
constraints.append(p[5] >= 0)
constraints.append(i[0] >= 0)
constraints.append(i[1] >= 0)
constraints.append(i[2] >= 0)
constraints.append(i[3] >= 0)
constraints.append(i[4] >= 0)
constraints.append(i[5] >= 0)
constraints.append(i[6] >= 0)
constraints.append(i[7] >= 0)
constraints.append(i[8] >= 0)
constraints.append(i[9] >= 0)
constraints.append(i[10] >= 0)
constraints.append(i[11] >= 0)
constraints.append(i[12] >= 0)
constraints.append(i[13] >= 0)
constraints.append(i[14] >= 0)
constraints.append(p[0] <= 1)
constraints.append(p[1] <= 1)
constraints.append(p[2] <= 1)
constraints.append(p[3] <= 1)
constraints.append(p[4] <= 1)
constraints.append(p[5] <= 1)
constraints.append(i[0] <= 1)
constraints.append(i[1] <= 1)
constraints.append(i[2] <= 1)
constraints.append(i[3] <= 1)
constraints.append(i[4] <= 1)
constraints.append(i[5] <= 1)
constraints.append(i[6] <= 1)
constraints.append(i[7] <= 1)
constraints.append(i[8] <= 1)
constraints.append(i[9] <= 1)
constraints.append(i[10] <= 1)
constraints.append(i[11] <= 1)
constraints.append(i[12] <= 1)
constraints.append(i[13] <= 1)
constraints.append(i[14] <= 1)


problem = cp.Problem(cp.Maximize(obj_func), constraints)


problem.solve(solver=cp.GUROBI, verbose = True)

print("obj_func =")
print(obj_func.value)
print("p =")
print(p.value)
print("i = ")
print(i.value)
# Out:
# ...
#                                      CVXPY
#                                      v1.3.2
# ...
# (CVXPY) Nov 29 02:25:56 PM: Your problem has 21 variables, 49 constraints, and 0 parameters.
# (CVXPY) Nov 29 02:25:56 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 29 02:25:56 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 29 02:25:56 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 29 02:25:56 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Nov 29 02:25:56 PM: Reduction chain: FlipObjective -> CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# ...

# %%
p = cp.Variable(6, integer = True)
i = cp.Variable(15, integer = True)

obj_func = 250*p[0] + 180*p[1] + 150*p[2] + 170*p[3] + 210*p[4] + 150*p[5] + 210*i[0] + 210*i[1] + 130*i[2] + 130*i[3] + 230*i[4] + 25*i[5] + 80*i[6] + 15*i[7] + 30*i[8] + 110*i[9] + 20*i[10] + 110*i[11] + 5*i[12] + 120*i[13] + 320*i[14]

constraints = []

constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] >= 17)
constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] <= 59)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] >= 75)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] <= 100)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] >= 15)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] <= 30)
constraints.append(11.75*p[0] + 8.75*p[1] + 10.5*p[2] + 10.5*p[3] + 9.4*p[4] + 8.75*p[5] + 2.65*i[4] + 1.55*i[13] + .5*i[14] <= 10.00)
constraints.append(p[0] >= 0)
constraints.append(p[1] >= 0)
constraints.append(p[2] >= 0)
constraints.append(p[3] >= 0)
constraints.append(p[4] >= 0)
constraints.append(p[5] >= 0)
constraints.append(i[0] >= 0)
constraints.append(i[1] >= 0)
constraints.append(i[2] >= 0)
constraints.append(i[3] >= 0)
constraints.append(i[4] >= 0)
constraints.append(i[5] >= 0)
constraints.append(i[6] >= 0)
constraints.append(i[7] >= 0)
constraints.append(i[8] >= 0)
constraints.append(i[9] >= 0)
constraints.append(i[10] >= 0)
constraints.append(i[11] >= 0)
constraints.append(i[12] >= 0)
constraints.append(i[13] >= 0)
constraints.append(i[14] >= 0)
constraints.append(p[0] <= 1)
constraints.append(p[1] <= 1)
constraints.append(p[2] <= 1)
constraints.append(p[3] <= 1)
constraints.append(p[4] <= 1)
constraints.append(p[5] <= 1)
constraints.append(i[0] <= 1)
constraints.append(i[1] <= 1)
constraints.append(i[2] <= 1)
constraints.append(i[3] <= 1)
constraints.append(i[4] <= 1)
constraints.append(i[5] <= 1)
constraints.append(i[6] <= 1)
constraints.append(i[7] <= 1)
constraints.append(i[8] <= 1)
constraints.append(i[9] <= 1)
constraints.append(i[10] <= 1)
constraints.append(i[11] <= 1)
constraints.append(i[12] <= 1)
constraints.append(i[13] <= 1)
constraints.append(i[14] <= 1)


problem = cp.Problem(cp.Maximize(obj_func), constraints)


problem.solve(solver=cp.GUROBI, verbose = True)

print("obj_func =")
print(obj_func.value)
print("p =")
print(p.value)
print("i = ")
print(i.value)
# Out:
# ...
#                                      CVXPY
#                                      v1.3.2
# ...
# (CVXPY) Nov 29 02:26:06 PM: Your problem has 21 variables, 49 constraints, and 0 parameters.
# (CVXPY) Nov 29 02:26:06 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 29 02:26:06 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 29 02:26:06 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 29 02:26:06 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Nov 29 02:26:06 PM: Reduction chain: FlipObjective -> CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# ...

# %%
p = cp.Variable(6, integer = True)
i = cp.Variable(15, integer = True)

obj_func = 250*p[0] + 180*p[1] + 150*p[2] + 170*p[3] + 210*p[4] + 150*p[5] + 210*i[0] + 210*i[1] + 130*i[2] + 130*i[3] + 230*i[4] + 25*i[5] + 80*i[6] + 15*i[7] + 30*i[8] + 110*i[9] + 20*i[10] + 110*i[11] + 5*i[12] + 120*i[13] + 320*i[14]

constraints = []

constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] >= 17)
constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] <= 59)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] >= 75)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] <= 100)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] >= 15)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] <= 30)
constraints.append(11.75*p[0] + 8.75*p[1] + 10.5*p[2] + 10.5*p[3] + 9.4*p[4] + 8.75*p[5] + 2.65*i[4] + 1.55*i[13] + .5*i[14] <= 12.00)
constraints.append(p[0] >= 0)
constraints.append(p[1] >= 0)
constraints.append(p[2] >= 0)
constraints.append(p[3] >= 0)
constraints.append(p[4] >= 0)
constraints.append(p[5] >= 0)
constraints.append(i[0] >= 0)
constraints.append(i[1] >= 0)
constraints.append(i[2] >= 0)
constraints.append(i[3] >= 0)
constraints.append(i[4] >= 0)
constraints.append(i[5] >= 0)
constraints.append(i[6] >= 0)
constraints.append(i[7] >= 0)
constraints.append(i[8] >= 0)
constraints.append(i[9] >= 0)
constraints.append(i[10] >= 0)
constraints.append(i[11] >= 0)
constraints.append(i[12] >= 0)
constraints.append(i[13] >= 0)
constraints.append(i[14] >= 0)
constraints.append(p[0] <= 1)
constraints.append(p[1] <= 1)
constraints.append(p[2] <= 1)
constraints.append(p[3] <= 1)
constraints.append(p[4] <= 1)
constraints.append(p[5] <= 1)
constraints.append(i[0] <= 1)
constraints.append(i[1] <= 1)
constraints.append(i[2] <= 1)
constraints.append(i[3] <= 1)
constraints.append(i[4] <= 1)
constraints.append(i[5] <= 1)
constraints.append(i[6] <= 1)
constraints.append(i[7] <= 1)
constraints.append(i[8] <= 1)
constraints.append(i[9] <= 1)
constraints.append(i[10] <= 1)
constraints.append(i[11] <= 1)
constraints.append(i[12] <= 1)
constraints.append(i[13] <= 1)
constraints.append(i[14] <= 1)


problem = cp.Problem(cp.Maximize(obj_func), constraints)


problem.solve(solver=cp.GUROBI, verbose = True)

print("obj_func =")
print(obj_func.value)
print("p =")
print(p.value)
print("i = ")
print(i.value)

# %%
p = cp.Variable(6, integer = True)
i = cp.Variable(15, integer = True)

obj_func = 250*p[0] + 180*p[1] + 150*p[2] + 170*p[3] + 210*p[4] + 150*p[5] + 210*i[0] + 210*i[1] + 130*i[2] + 130*i[3] 
+ 230*i[4] + 25*i[5] + 80*i[6] + 15*i[7] + 30*i[8] + 110*i[9] + 20*i[10] + 110*i[11] + 5*i[12] + 120*i[13] + 320*i[14]

constraints = []

constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] 
                   + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] >= 17)
constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] 
                   + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] <= 59)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] 
                   + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] >= 75)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] 
                   + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] <= 100)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] 
                   + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] >= 15)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] 
                   + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] <= 30)
constraints.append(11.75*p[0] + 8.75*p[1] + 10.5*p[2] + 10.5*p[3] + 9.4*p[4] + 8.75*p[5] + 2.65*i[4] + 1.55*i[13] 
                   + .5*i[14] <= 12.00)
constraints.append(p[0] >= 0)
constraints.append(p[1] >= 0)
constraints.append(p[2] >= 0)
constraints.append(p[3] >= 0)
constraints.append(p[4] >= 0)
constraints.append(p[5] >= 0)
constraints.append(i[0] >= 0)
constraints.append(i[1] >= 0)
constraints.append(i[2] >= 0)
constraints.append(i[3] >= 0)
constraints.append(i[4] >= 0)
constraints.append(i[5] >= 0)
constraints.append(i[6] >= 0)
constraints.append(i[7] >= 0)
constraints.append(i[8] >= 0)
constraints.append(i[9] >= 0)
constraints.append(i[10] >= 0)
constraints.append(i[11] >= 0)
constraints.append(i[12] >= 0)
constraints.append(i[13] >= 0)
constraints.append(i[14] >= 0)
constraints.append(p[0] <= 1)
constraints.append(p[1] <= 1)
constraints.append(p[2] <= 1)
constraints.append(p[3] <= 1)
constraints.append(p[4] <= 1)
constraints.append(p[5] <= 1)
constraints.append(i[0] <= 1)
constraints.append(i[1] <= 1)
constraints.append(i[2] <= 1)
constraints.append(i[3] <= 1)
constraints.append(i[4] <= 1)
constraints.append(i[5] <= 1)
constraints.append(i[6] <= 1)
constraints.append(i[7] <= 1)
constraints.append(i[8] <= 1)
constraints.append(i[9] <= 1)
constraints.append(i[10] <= 1)
constraints.append(i[11] <= 1)
constraints.append(i[12] <= 1)
constraints.append(i[13] <= 1)
constraints.append(i[14] <= 1)


problem = cp.Problem(cp.Maximize(obj_func), constraints)


problem.solve(solver=cp.GUROBI, verbose = True)

print("obj_func =")
print(obj_func.value)
print("p =")
print(p.value)
print("i = ")
print(i.value)
# Out:
# ...
#                                      CVXPY
#                                      v1.3.2
# ...
# (CVXPY) Nov 29 02:38:03 PM: Your problem has 21 variables, 49 constraints, and 0 parameters.
# (CVXPY) Nov 29 02:38:03 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 29 02:38:03 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 29 02:38:03 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 29 02:38:03 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Nov 29 02:38:03 PM: Reduction chain: FlipObjective -> CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# ...

# %%
p = cp.Variable(6, integer = True)
i = cp.Variable(15, integer = True)

obj_func = 250*p[0] + 180*p[1] + 150*p[2] + 170*p[3] + 210*p[4] + 150*p[5] + 210*i[0] + 210*i[1] + 130*i[2] + 130*i[3] 
+ 230*i[4] + 25*i[5] + 80*i[6] + 15*i[7] + 30*i[8] + 110*i[9] + 20*i[10] + 110*i[11] + 5*i[12] + 120*i[13] + 320*i[14]

constraints = []

constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] 
                   + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] >= 17)
constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] 
                   + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] <= 59)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] 
                   + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] >= 75)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] 
                   + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] <= 100)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] 
                   + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] >= 15)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] 
                   + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] <= 30)
constraints.append(11.75*p[0] + 8.75*p[1] + 10.5*p[2] + 10.5*p[3] + 9.4*p[4] + 8.75*p[5] + 2.65*i[4] + 1.55*i[13] 
                   + .5*i[14] <= 11.00)
constraints.append(p[0] >= 0)
constraints.append(p[1] >= 0)
constraints.append(p[2] >= 0)
constraints.append(p[3] >= 0)
constraints.append(p[4] >= 0)
constraints.append(p[5] >= 0)
constraints.append(i[0] >= 0)
constraints.append(i[1] >= 0)
constraints.append(i[2] >= 0)
constraints.append(i[3] >= 0)
constraints.append(i[4] >= 0)
constraints.append(i[5] >= 0)
constraints.append(i[6] >= 0)
constraints.append(i[7] >= 0)
constraints.append(i[8] >= 0)
constraints.append(i[9] >= 0)
constraints.append(i[10] >= 0)
constraints.append(i[11] >= 0)
constraints.append(i[12] >= 0)
constraints.append(i[13] >= 0)
constraints.append(i[14] >= 0)
constraints.append(p[0] <= 1)
constraints.append(p[1] <= 1)
constraints.append(p[2] <= 1)
constraints.append(p[3] <= 1)
constraints.append(p[4] <= 1)
constraints.append(p[5] <= 1)
constraints.append(i[0] <= 1)
constraints.append(i[1] <= 1)
constraints.append(i[2] <= 1)
constraints.append(i[3] <= 1)
constraints.append(i[4] <= 1)
constraints.append(i[5] <= 1)
constraints.append(i[6] <= 1)
constraints.append(i[7] <= 1)
constraints.append(i[8] <= 1)
constraints.append(i[9] <= 1)
constraints.append(i[10] <= 1)
constraints.append(i[11] <= 1)
constraints.append(i[12] <= 1)
constraints.append(i[13] <= 1)
constraints.append(i[14] <= 1)


problem = cp.Problem(cp.Maximize(obj_func), constraints)


problem.solve(solver=cp.GUROBI, verbose = True)

print("obj_func =")
print(obj_func.value)
print("p =")
print(p.value)
print("i = ")
print(i.value)
# Out:
# ...
#                                      CVXPY
#                                      v1.3.2
# ...
# (CVXPY) Nov 29 02:40:58 PM: Your problem has 21 variables, 49 constraints, and 0 parameters.
# (CVXPY) Nov 29 02:40:58 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 29 02:40:58 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 29 02:40:58 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 29 02:40:58 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Nov 29 02:40:58 PM: Reduction chain: FlipObjective -> CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# ...

# %%
p = cp.Variable(6, integer = True)
i = cp.Variable(15, integer = True)

obj_func = 250*p[0] + 180*p[1] + 150*p[2] + 170*p[3] + 210*p[4] + 150*p[5] + 210*i[0] + 210*i[1] + 130*i[2] + 130*i[3] + 230*i[4] + 25*i[5] + 80*i[6] + 15*i[7] + 30*i[8] + 110*i[9] + 20*i[10] + 110*i[11] + 5*i[12] + 120*i[13] + 320*i[14]

constraints = []

constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] >= 17)
constraints.append(29*p[0] + 32*p[1] + 21*p[2] + 24*p[3] + 23*p[4] + 8*p[5] + 4*i[0] + 4*i[1] + 8*i[2] + 8*i[3] + 2*i[4] + 3*i[6] + 2*i[9] + 1*i[10] + 6*i[11] +5*i[13] + 8*i[14] <= 59)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] >= 75)
constraints.append(1*p[0] + 3*p[2] + 2*p[3] + 9*p[5] + 40*i[0] + 36*i[1] + 22*i[2] + 21*i[3] + 8*i[4] + 4*i[5] + 16*i[6] + 4*i[7] + 4*i[8] + 2*i[9] + 5*i[10] + 1*i[11] + 1*i[12] + 4*i[13]  + 50*i[14] <= 100)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] >= 15)
constraints.append(14*p[0] + 7*p[1] + 6*p[2] + 7*p[3] + 12*p[4] + 10*p[5] + 4*i[0] + 6*i[1] + 2*i[2] + 2*i[3] + 22*i[4] + 2*i[6] + 9*i[9] + 8*i[11] + 9*i[13] + 9*i[14] <= 30)
constraints.append(11.75*p[0] + 8.75*p[1] + 10.5*p[2] + 10.5*p[3] + 9.4*p[4] + 8.75*p[5] + 2.65*i[4] + 1.55*i[13] + .5*i[14] <= 12.00)
constraints.append(p[0] >= 0)
constraints.append(p[1] >= 0)
constraints.append(p[2] >= 0)
constraints.append(p[3] >= 0)
constraints.append(p[4] >= 0)
constraints.append(p[5] >= 0)
constraints.append(i[0] >= 0)
constraints.append(i[1] >= 0)
constraints.append(i[2] >= 0)
constraints.append(i[3] >= 0)
constraints.append(i[4] >= 0)
constraints.append(i[5] >= 0)
constraints.append(i[6] >= 0)
constraints.append(i[7] >= 0)
constraints.append(i[8] >= 0)
constraints.append(i[9] >= 0)
constraints.append(i[10] >= 0)
constraints.append(i[11] >= 0)
constraints.append(i[12] >= 0)
constraints.append(i[13] >= 0)
constraints.append(i[14] >= 0)
constraints.append(p[0] <= 1)
constraints.append(p[1] <= 1)
constraints.append(p[2] <= 1)
constraints.append(p[3] <= 1)
constraints.append(p[4] <= 1)
constraints.append(p[5] <= 1)
constraints.append(i[0] <= 1)
constraints.append(i[1] <= 1)
constraints.append(i[2] <= 1)
constraints.append(i[3] <= 1)
constraints.append(i[4] <= 1)
constraints.append(i[5] <= 1)
constraints.append(i[6] <= 1)
constraints.append(i[7] <= 1)
constraints.append(i[8] <= 1)
constraints.append(i[9] <= 1)
constraints.append(i[10] <= 1)
constraints.append(i[11] <= 1)
constraints.append(i[12] <= 1)
constraints.append(i[13] <= 1)
constraints.append(i[14] <= 1)


problem = cp.Problem(cp.Minimize(obj_func), constraints)


problem.solve(solver=cp.GUROBI, verbose = True)

print("obj_func =")
print(obj_func.value)
print("p =")
print(p.value)
print("i = ")
print(i.value)
# Out:
# ...
#                                      CVXPY
#                                      v1.3.2
# ...
# (CVXPY) Nov 29 04:24:08 PM: Your problem has 21 variables, 49 constraints, and 0 parameters.
# (CVXPY) Nov 29 04:24:08 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 29 04:24:08 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 29 04:24:08 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 29 04:24:08 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Nov 29 04:24:08 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Nov 29 04:24:08 PM: Applying reduction CvxAttr2Constr
# ...
